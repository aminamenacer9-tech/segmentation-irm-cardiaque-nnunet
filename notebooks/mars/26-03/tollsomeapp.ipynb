# %%
import nibabel as nb
from matplotlib import pyplot as plt
import numpy as np

# %%
img_nii = nb.load('/home/amenacer/Stage/Data/TollSome/Anat/Groupe2/TollC3S1B_Original_0000.nii.gz')

# %%
print(img_nii)

# %%
mat = img_nii.get_fdata()

# %%
print(mat.shape)

# %%
np.median(mat)

# %%
plt.imshow(mat[:, :, 15])
plt.show()

# %%
mask_nii = nb.load('/home/amenacer/Stage/Data/Tollsomemask/Groupe2/TollC3S1B_Original.nii.gz')

# %%
mat_mask = mask_nii.get_fdata()
plt.imshow(mat_mask[:, :, 15])
